# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(temperature=0.7, model="llama-3.3-70b-versatile")

# %%
response=llm.invoke("Write a cold email to get clients for a freelance web developer.")

# %%
response.content
# Out:
# "Here's a sample cold email that a freelance web developer could send to potential clients:\n\nSubject: Expert Web Development Services for Your Business\n\nDear [Recipient's Name],\n\nI came across your company, [Company Name], and was impressed by the great work you're doing in [industry/field]. As a freelance web developer with a passion for creating innovative and user-friendly websites, I thought I'd reach out to see if I could help take your online presence to the next level.\n\nWith [number of years] years of experience in web development, I've helped numerous businesses like yours achieve their online goals through custom website design, development, and optimization. My expertise includes:\n\n* Building fast, secure, and responsive websites using the latest technologies (HTML, CSS, JavaScript, etc.)\n* Creating e-commerce solutions that drive sales and conversions\n* Developing custom web applications that streamline business processes\n* Improving website performance and se
# ...

# %%
import chromadb
client=chromadb.Client()
collection=client.get_or_create_collection(name="cold_emails")

# %%
collection.add(
    documents=[
        "This document is about Rajasthan",
        "This document is about Bikaner",
        "This document is about Delhi",
        "This document is about Haryana"
    ],
    ids=["doc1", "doc2", "doc3", "doc4"]
)

# %%
collection.get()
# Out:
# {'ids': ['doc1', 'doc2', 'doc3', 'doc4'],
#  'embeddings': None,
#  'documents': ['This document is about Rajasthan',
#   'This document is about Bikaner',
#   'This document is about Delhi',
#   'This document is about Haryana'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None, None, None]}

# %%
collection.get(ids=["doc2"])
# Out:
# {'ids': ['doc2'],
#  'embeddings': None,
#  'documents': ['This document is about Bikaner'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None]}

# %%
collection.query(
    query_texts=["bridges"],
    n_results=4
)
# Out:
# {'ids': [['doc2', 'doc3', 'doc1', 'doc4']],
#  'embeddings': None,
#  'documents': [['This document is about Bikaner',
#    'This document is about Delhi',
#    'This document is about Rajasthan',
#    'This document is about Haryana']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None, None, None]],
#  'distances': [[1.7649505138397217,
#    1.7852563858032227,
#    1.8698201179504395,
#    1.9211175441741943]]}

# %%
collection.delete(ids=["doc1", "doc2", "doc3", "doc4"])

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids=["id1", "id2"],
    metadatas=[
        {"url": "https://en.wikipedia.org/wiki/New_York_City"},
        {"url": "https://en.wikipedia.org/wiki/New_Delhi"}
    ]
)

# %%
collection.get()
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This document is about New York',
#   'This document is about Delhi'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'url': 'https://en.wikipedia.org/wiki/New_York_City'},
#   {'url': 'https://en.wikipedia.org/wiki/New_Delhi'}]}

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://internshala.com/jobs/")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
# Jobs: 15381 Job Vacancies & Openings in India | Search Jobs Online
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upskill and land your dream career - Limited period offer! Know More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cancel
# Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close
# Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cancel
# Yes
#
#
#
#
#
#
#
#
#
#
#
#
#         Oops, your browser does not support Javascript. Please use Internshala in another browser.
#
#
#
#
#
#             Loading, please wait...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         Student
#
#
#                                         Employer / T&P
#
#
#
#
#
#
#
#
#
#
#                                         Login with Google
#
#
#
#
#
# OR
#
#
#
#
#
#
# Email
#
#
#
# Password
#
#
#
# ...

# %%
page_data
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n \n\n\n\n\nJobs: 15381 Job Vacancies & Openings in India | Search Jobs Online\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\nUpskill and land your dream career - Limited period offer! Know More \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nClose\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCancel\nClose\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nClose\nClose\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nClose\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCancel\nYes\n\n\n\n\n\n\n\n\n\n\n\n\n        Oops, your browser does not support Javascript. Please use Internshala in another browser.\n    \n\n\n\n\n            Loading, please wait...\n        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                        Student\n                                    \n\n                                        Employer / T&P\n                                    \n\n\n\n\n\n\n\n\n\n                         
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `company`, `domain`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data[:20000]})  # Limiting to first 20k chars
print(res.content)
type(res.content)
# Out:
# ```json
# [
#   {
#     "role": "AI Engineer",
#     "company": "Bryckel AI",
#     "domain": "Technology",
#     "experience": "1 year",
#     "skills": ["Python", "PostgreSQL", "Claude", "Gemini", "Amazon EC2", "Amazon RDS", "Django Rest Framework"],
#     "description": "Perform OCR on scanned lease documents before analysis, preprocess extracted text for reliable AI model consumption, build and maintain pipelines for complex document processing and extraction, ensure structured, consistent output from AI models, implement preferred/fallback language handling in extracted recommendations, apply deduplication and merging logic to AI outputs, integrate document parsing, backend, and database storage, set up basic monitoring, retries, and logging for LLM API calls, iteratively improve prompts and outputs in collaboration with domain experts."
#   },
#   {
#     "role": "Academic Counselor",
#     "company": "PlanetSpark",
#     "domain": "Education",
#     "experience": "0 year",
# ...

# %%
from langchain_core.output_parsers import JsonOutputParser
json_parser=JsonOutputParser()
json_res=json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Software Engineer',
#   'company': 'Mercor',
#   'domain': 'Technology',
#   'experience': '2-5 years',
#   'skills': ['Python', 'Java', 'Cloud Computing'],
#   'description': 'Design, develop, and test software applications'},
#  {'role': 'Data Scientist',
#   'company': 'Mercor',
#   'domain': 'Data Analytics',
#   'experience': '5-10 years',
#   'skills': ['Machine Learning', 'Data Visualization', 'Statistics'],
#   'description': 'Analyze and interpret complex data to inform business decisions'},
#  {'role': 'Product Manager',
#   'company': 'Mercor',
#   'domain': 'Product Management',
#   'experience': '5-10 years',
#   'skills': ['Product Development', 'Market Research', 'Leadership'],
#   'description': 'Develop and launch new products to drive business growth'}]

# %%
type(json_res)
# Out:
# list

# %%
import pandas as pd
df=pd.read_csv("my_portfolio.csv")

# %%
df.head()
# Out:
#                            Techstack                                  Links
# 0            React, Node.js, MongoDB    https://example.com/react-portfolio
# 1           Angular,.NET, SQL Server  https://example.com/angular-portfolio
# 2  Vue.js, Ruby on Rails, PostgreSQL      https://example.com/vue-portfolio
# 3              Python, Django, MySQL   https://example.com/python-portfolio
# 4          Java, Spring Boot, Oracle     https://example.com/java-portfolio

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
links = collection.query(query_texts=["Experience in Python"], n_results=2).get('metadatas', [])
links
# Out:
# [[{'link': 'https://example.com/ml-python-portfolio'},
#   {'link': 'https://example.com/python-portfolio'}]]

# %%
json_res
# Out:
# [{'role': 'Software Engineer',
#   'company': 'Mercor',
#   'domain': 'Technology',
#   'experience': '2-5 years',
#   'skills': ['Python', 'Java', 'Cloud Computing'],
#   'description': 'Design, develop, and test software applications'},
#  {'role': 'Data Scientist',
#   'company': 'Mercor',
#   'domain': 'Data Analytics',
#   'experience': '5-10 years',
#   'skills': ['Machine Learning', 'Data Visualization', 'Statistics'],
#   'description': 'Analyze and interpret complex data to inform business decisions'},
#  {'role': 'Product Manager',
#   'company': 'Mercor',
#   'domain': 'Product Management',
#   'experience': '5-10 years',
#   'skills': ['Product Development', 'Market Research', 'Leadership'],
#   'description': 'Develop and launch new products to drive business growth'}]

# %%
job=json_res
job[1]['skills']
# Out:
# ['Machine Learning', 'Data Visualization', 'Statistics']

# %%
links = collection.query(query_texts=job[1]['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'link': 'https://example.com/ml-python-portfolio'},
#   {'link': 'https://example.com/wordpress-portfolio'}],
#  [{'link': 'https://example.com/magento-portfolio'},
#   {'link': 'https://example.com/wordpress-portfolio'}],
#  [{'link': 'https://example.com/ios-portfolio'},
#   {'link': 'https://example.com/ml-python-portfolio'}]]

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Solutions for Mercor's Technology and Data Analytics Needs
#
# Dear Hiring Manager at Mercor,
#
# I came across the job openings at Mercor and was impressed by the company's commitment to innovation and excellence. As a Business Development Executive at AtliQ, an AI & Software Consulting company, I believe our expertise can help fulfill your requirements.
#
# We have a proven track record of delivering tailored solutions that drive business growth, scalability, and process optimization. Our team of experts can design, develop, and test software applications, analyze complex data, and develop new products to inform business decisions.
#
# For the Software Engineer role, our proficiency in Python, Java, and Cloud Computing can help Mercor develop and deploy scalable software applications. We have successfully implemented similar projects, as showcased in our portfolio: https://example.com/ml-python-portfolio.
#
# ...

# %%
links
# Out:
# [[{'link': 'https://example.com/ml-python-portfolio'},
#   {'link': 'https://example.com/wordpress-portfolio'}],
#  [{'link': 'https://example.com/magento-portfolio'},
#   {'link': 'https://example.com/wordpress-portfolio'}],
#  [{'link': 'https://example.com/ios-portfolio'},
#   {'link': 'https://example.com/ml-python-portfolio'}]]

# %%
job
# Out:
# [{'role': 'Software Engineer',
#   'company': 'Mercor',
#   'domain': 'Technology',
#   'experience': '2-5 years',
#   'skills': ['Python', 'Java', 'Cloud Computing'],
#   'description': 'Design, develop, and test software applications'},
#  {'role': 'Data Scientist',
#   'company': 'Mercor',
#   'domain': 'Data Analytics',
#   'experience': '5-10 years',
#   'skills': ['Machine Learning', 'Data Visualization', 'Statistics'],
#   'description': 'Analyze and interpret complex data to inform business decisions'},
#  {'role': 'Product Manager',
#   'company': 'Mercor',
#   'domain': 'Product Management',
#   'experience': '5-10 years',
#   'skills': ['Product Development', 'Market Research', 'Leadership'],
#   'description': 'Develop and launch new products to drive business growth'}]
